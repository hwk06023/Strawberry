# %%
import cv2
from matplotlib.pyplot import imshow
import numpy as np
from PIL import Image

# %%
img_list = []

for i in range(52):
    img_list.append(cv2.imread('data/%d.png' % (i)))
    img_list[i] = cv2.cvtColor(img_list[i], cv2.COLOR_BGR2RGB)
    
print(len(img_list))
# Out:
# 52

# %%
imshow(np.asarray(img_list[1]))

# %%
print(img_list[1][0][0])
print(len(img_list[1][0]))
print(len(img_list[1]))
# Out:
# [78 94 93]
# 2992
# 2992

# %%
for i in range(200): print(img_list[1][1000+i][1800]) # R G B
# Out:
# [175  45  19]
# [177  47  21]
# [175  45  21]
# [173  43  19]
# [173  43  19]
# [171  43  18]
# [168  42  19]
# [169  43  20]
# [174  50  26]
# [173  49  25]
# [168  44  20]
# [164  40  16]
# [166  42  18]
# [164  40  16]
# [159  37  13]
# [159  37  13]
# [161  39  15]
# [164  42  18]
# [165  43  19]
# [162  40  16]
# [161  39  15]
# [162  40  16]
# [162  42  17]
# [161  41  16]
# [158  39  15]
# [161  42  18]
# [161  42  18]
# [159  40  16]
# [157  38  14]
# [156  37  13]
# [159  40  16]
# [157  38  14]
# [155  36  12]
# [160  41  17]
# [162  43  19]
# [159  40  16]
# [154  35  11]
# [156  37  13]
# [159  40  16]
# [159  40  16]
# [158  39  17]
# [159  40  18]
# [160  41  19]
# [161  42  20]
# [161  42  20]
# [158  39  17]
# [156  37  15]
# [157  38  16]
# [155  36  14]
# [153  34  12]
# [154  35  13]
# [156  37  15]
# [156  37  15]
# [160  41  19]
# [163  44  22]
# [162  43  21]
# [161  45  22]
# [157  41  18]
# [156  40  17]
# [151  35  12]
# [153  37  14]
# [153  37  14]
# ...
