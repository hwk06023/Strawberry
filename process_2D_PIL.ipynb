# %%
import os
import glob
import matplotlib.pyplot as plt
import numpy as np
import cv2
from PIL import Image

# %%
pil_imgs = sorted(glob.glob("data/*.png"))

# %%
pil_imgs[:5]
# Out:
# ['data/0.png', 'data/1.png', 'data/10.png', 'data/11.png', 'data/12.png']

# %%
pil_imgs = []

for i in range(52):
    pil_imgs.append(Image.open('data/%d.png' % (i)))
    # .jpeg(original) -> .png
    # pil_img[i].save(r'data/%d.png' % (i))

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 15))

axs[0].imshow(pil_imgs[1])
axs[1].imshow(pil_imgs[10])

# %%
import copy

image = copy.deepcopy(np.array(pil_imgs[1]))

# %%
plt.imshow(image)

# %%
image = (image >=(50)).astype('float')
plt.imshow(image)

# %%
image[1200][1200]
# Out:
# array([1., 0., 0.])

# %%
strbry = []

for i in range(len(image)):
    for j in range(len(image[i])):
        if (image[i][j][0] > 0.5 and image[i][j][1] < 0.5 and image[i][j][2] < 0.5):
            strbry.append([i, j])
        else:
            image[i][j] = [0, 0, 0]

# %%
len(strbry)
# Out:
# 216530

# %%
print(strbry[0:len(strbry):10000])
# Out:
# [[644, 438], [836, 914], [884, 940], [923, 1077], [960, 1102], [994, 885], [1025, 1141], [1052, 946], [1078, 1047], [1102, 933], [1125, 1192], [1148, 1131], [1172, 1132], [1198, 1019], [1226, 1328], [1253, 1239], [1282, 1245], [1312, 1037], [1347, 1086], [1388, 1296], [1509, 1089], [1915, 1927]]

# %%
plt.imshow(image)
